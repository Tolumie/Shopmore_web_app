# %% [markdown]
# # ShopMore Retail Mall: Customer Segmentation Using K-Means Clustering
#
# ## Project Overview and Objective
# The goal of this project is to segment customers of ShopMore Retail Mall using K-Means clustering. Customer segmentation is a crucial step in understanding different customer groups, which allows for tailoring marketing strategies to each segment's characteristics. The dataset used includes demographic and spending behavior data, focusing on customers' annual income and spending scores.
#
# **Objective:**
# The primary objective is to cluster customers into groups that exhibit similar behaviors, using K-Means clustering to identify shared traits in each segment. This segmentation provides insights for creating targeted marketing campaigns, personalized offers, and optimizing resources for better customer engagement.
#
# ---
#
# ## Step 1: Data Preparation and Exploratory Data Analysis
#
# ### Data Description and Structure
# The dataset consists of 50,000 records with the following columns:
# - **Customer ID**: Unique identifier for each customer.
# - **Gender**: Male or Female.
# - **Age**: Customer's age in years.
# - **Annual Income (k$)**: Income measured in thousands of dollars.
# - **Spending Score (1-100)**: Score assigned based on spending behavior (higher scores indicate more spending).
#
# For clustering, we select 'Annual Income (k$)' and 'Spending Score (1-100)' as our primary features, as these metrics capture the key financial characteristics relevant to marketing.
#
# ### Data Cleaning
# The dataset is reviewed to ensure quality:
# - **Missing Values:** There are no missing values in the dataset, confirming it is ready for analysis.
# - **Duplicates and Inconsistencies:** We find no duplicate entries or inconsistencies that could affect the clustering analysis.
#
# ### Exploratory Data Analysis (EDA)
# The EDA aims to understand the distribution and relationships in the dataset before applying machine learning techniques:
# - **Descriptive Statistics:**
#   - Annual incomes range from $15k to $137k, while spending scores vary between 1 and 99.
#   - These wide ranges indicate a diverse customer base in terms of financial status and purchasing behavior.
# - **Data Distribution:**
#   - Histograms show that both annual income and spending score are not uniformly distributed, suggesting distinct customer groups might exist.
# - **Correlation Analysis:**
#   - The correlation between income and spending score is weak, indicating that higher income does not necessarily lead to higher spending. This suggests the need for segmentation to uncover more complex relationships.
#
# ---
#
# ## Step 2: Clustering Analysis Using K-Means
#
# ### Determining the Optimal Number of Clusters
# To choose an appropriate number of clusters (k), we employ the Elbow Method:
# - **Elbow Method:**
#   - We plot the within-cluster sum of squares (WCSS) for various cluster numbers (k values).
#   - The plot shows a noticeable "elbow" at k=5, suggesting that five clusters adequately capture the structure of the data without overfitting.
#
# ### Implementing K-Means Clustering
# Using k=5, we apply the K-Means algorithm to the dataset:
# - **Cluster Assignment:**
#   - The algorithm assigns each customer to one of the five clusters, based on the similarity in annual income and spending score.
# - **Centroids Calculation:**
#   - Centroids, representing the center of each cluster, are calculated to help interpret the cluster characteristics.
#
# ---
#
# ## Step 3: Analysis and Interpretation of Clustering Results
#
# ### Cluster Characteristics
# Based on the clustering output, we derive the following profiles for each group:
#
# - **Cluster 0:**
#   - **Profile:** Middle-aged (average age 43), moderate income ($55k), and moderate spending (Spending Score: 50).
#   - **Predominant Gender:** Male.
#   - **Insights:** Represents a balanced group with stable spending and income levels.
#
# - **Cluster 1:**
#   - **Profile:** Average age 41, high income ($88k), but with a low spending score (17).
#   - **Predominant Gender:** Female.
#   - **Insights:** High-income customers who spend cautiously. This group values savings or is selective about their purchases.
#
# - **Cluster 2:**
#   - **Profile:** Younger (average age 33), high income ($87k), and high spending behavior (Spending Score: 82).
#   - **Predominant Gender:** Male.
#   - **Insights:** High-spending and high-income customers, likely driven by lifestyle purchases.
#
# - **Cluster 3:**
#   - **Profile:** Older (average age 45), lower income ($26k), and low spending score (20).
#   - **Predominant Gender:** Male.
#   - **Insights:** Budget-conscious group with limited financial means, likely to respond well to value-driven offers.
#
# - **Cluster 4:**
#   - **Profile:** Youngest group (average age 25), lower income ($26k), but a high spending score (79).
#   - **Predominant Gender:** Male.
#   - **Insights:** This segment includes younger customers who prioritize lifestyle and experiences despite lower incomes.
#
# ---
#
# ## Step 4: Visualization of Clusters
# Visualizing the clusters helps us confirm the distinct groupings:
# - **PCA Plot:**
#   - A PCA (Principal Component Analysis) plot shows some clusters are more dispersed, indicating varied customer behaviors, while others are more compact, reflecting similar purchasing habits.
# - **2D Scatter Plot:**
#   - We plot clusters on a 2D plane with annual income and spending score on the axes, which clearly separates the clusters and illustrates their characteristics.
#
# ---
#
# ## Step 5: Developing Targeted Marketing Strategies
#
# Here’s how we tailor the marketing strategies for each cluster:
#
# ### Cluster 0 (Middle-aged, Moderate Income, Average Spending)
# - **Approach:** Offer mid-range products that provide quality at a reasonable price.
# - **Channels:** Utilize traditional channels like TV and print ads to reach this age group.
#
# ### Cluster 1 (High Income, Low Spending)
# - **Approach:** Entice spending with exclusive offers and luxury products. Consider loyalty programs to encourage more frequent purchases.
# - **Channels:** Personalized email campaigns emphasizing exclusivity.
#
# ### Cluster 2 (Younger, High Income, High Spending)
# - **Approach:** Promote aspirational products, such as high-end gadgets, travel experiences, or luxury fashion.
# - **Channels:** Leverage social media and influencer partnerships. Target ads based on lifestyle interests.
#
# ### Cluster 3 (Older, Low Income, Low Spending)
# - **Approach:** Focus on budget-friendly promotions and value-oriented deals.
# - **Channels:** Community events and local promotions resonate well with this group.
#
# ### Cluster 4 (Young, Low Income, High Spending)
# - **Approach:** Highlight youth-oriented experiences and lifestyle products.
# - **Channels:** Use platforms popular with young adults (e.g., Instagram, TikTok) and encourage user-generated content.
#
# ---
#
# ## Conclusion
# By segmenting our customers using K-Means clustering, we identify five distinct groups, each with unique characteristics and behaviors. Tailoring our marketing strategies to these clusters allows ShopMore Retail Mall to optimize marketing efforts, personalize customer engagement, and ultimately improve sales and customer satisfaction.
#
# The insights from this segmentation not only guide our marketing strategies but also provide a deeper understanding of our customer base, paving the way for data-driven decision-making in other areas of the business.

# %% [markdown]
# ### Step 1: Import Necessary Libraries

# %%
# Importing the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# Setting plot styles for better visualizations
sns.set(style="whitegrid")

# %% [markdown]
# Explanation:
# We import essential libraries: numpy and pandas for data manipulation, matplotlib and seaborn for plotting, and KMeans from sklearn for clustering. PCA is imported to reduce dimensionality for visualization.

# %% [markdown]
# ### Step 2: Load the Dataset

# %%
# Load the dataset
file_path = 'Shopmore_Retail.csv'  # Update this path to your file location
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0          98    Male   26           60.166809                      45
# 1         145    Male   23           76.114737                       7
# 2          43  Female   52           38.840794                      41
# 3         139  Female   24           74.782947                      14
# 4          14    Male   28           19.479408                      77

# %% [markdown]
# ### Explanation:
# The dataset is loaded from a CSV file named Mall_Customers.csv. We display the first few rows to get an overview of the data structure.

# %% [markdown]
# ### Step 3: Data Exploration and Cleaning

# %%
# Checking for missing values
print("Missing values in the dataset:")
print(data.isnull().sum())

# Checking for duplicates
print("\nNumber of duplicate rows in the dataset:", data.duplicated().sum())

# Summary statistics
data.describe()
# Out:
# Missing values in the dataset:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64
#
# Number of duplicate rows in the dataset: 0
#          CustomerID           Age  Annual Income (k$)  Spending Score (1-100)
# count  50000.000000  50000.000000        50000.000000            50000.000000
# mean     100.236600     38.965960           60.453140               50.189740
# std       57.699626     14.343027           26.269405               25.868074
# min        1.000000     13.000000            9.719208                1.000000
# 25%       50.000000     28.000000           41.151699               33.000000
# 50%      100.000000     37.000000           60.961985               50.000000
# 75%      150.000000     49.000000           77.135680               71.000000
# max      200.000000     75.000000          142.474101              100.000000

# %% [markdown]
# ### Insight:
# There are no missing values or duplicate records in the dataset, indicating that the data is clean and ready for analysis. The summary statistics give an overview of the ranges and central tendencies of each column.

# %% [markdown]
# ### Step 4: Exploratory Data Analysis (EDA)
# ### a) Visualize Data Distribution
#
# ## You can zoom in to view the chart more

# %%
# Distribution of Age, Annual Income, and Spending Score
fig, ax = plt.subplots(1, 3, figsize=(18, 6))

sns.histplot(data['Age'], bins=20, kde=True, ax=ax[0])
ax[0].set_title('Age Distribution')

sns.histplot(data['Annual Income (k$)'], bins=20, kde=True, ax=ax[1])
ax[1].set_title('Annual Income Distribution')

sns.histplot(data['Spending Score (1-100)'], bins=20, kde=True, ax=ax[2])
ax[2].set_title('Spending Score Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight:
# The histograms show that age, income, and spending scores are not evenly distributed, suggesting varied customer behaviors.

# %% [markdown]
# ### b) Correlation Analysis

# %%
# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']].corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Insight:
# The correlation heatmap shows a weak relationship between income and spending score, indicating that high income doesn't necessarily mean high spending, motivating the need for clustering.

# %% [markdown]
# ### Step 5: Data Preparation for Clustering

# %%
# Selecting features for clustering
X = data[['Annual Income (k$)', 'Spending Score (1-100)']]

# Displaying the first few rows of the selected features
X.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0           60.166809                      45
# 1           76.114737                       7
# 2           38.840794                      41
# 3           74.782947                      14
# 4           19.479408                      77

# %% [markdown]
# ### Explanation:
# We choose 'Annual Income' and 'Spending Score' for clustering since they represent financial characteristics relevant to customer segmentation.

# %% [markdown]
# ### Step 6: Determining Optimal Number of Clusters Using the Elbow Method

# %%
# Using the Elbow Method to find the optimal number of clusters
wcss = []  # List to store within-cluster sum of squares

# Calculating WCSS for different values of k
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# Plotting the Elbow Method results
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ### Insight:
# The plot shows a noticeable bend (elbow) at k=5, suggesting that five clusters should be chosen for the K-Means algorithm.

# %% [markdown]
# ### Step 7: Implementing K-Means Clustering

# %%
# Applying K-Means with k=5
kmeans = KMeans(n_clusters=5, init='k-means++', max_iter=300, n_init=10, random_state=42)
data['Cluster'] = kmeans.fit_predict(X)

# Save model with pickle for reuse
import pickle
pickle.dump(kmeans, open("kmeans.pkl", 'wb'))
# Displaying the first few rows with the assigned cluster labels
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0          98    Male   26           60.166809                      45
# 1         145    Male   23           76.114737                       7
# 2          43  Female   52           38.840794                      41
# 3         139  Female   24           74.782947                      14
# 4          14    Male   28           19.479408                      77
#
#    Cluster
# 0        0
# 1        2
# 2        0
# 3        2
# 4        3

# %% [markdown]
# ### Explanation:
# We apply K-Means clustering with five clusters. Each customer is assigned a cluster label, which is added as a new column in the dataset.

# %% [markdown]
# ### Step 8: Visualizing the Clusters
# a) 2D Scatter Plot

# %%
# Visualizing the clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster', data=data, palette='Set1', s=100, alpha=0.7)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='black', marker='X', label='Centroids')
plt.title('Customer Segments')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %% [markdown]
# ### Insight:
# The scatter plot clearly separates the five clusters, with different customer segments visible. The black 'X' markers indicate the centroids of each cluster.

# %% [markdown]
# ### b) PCA for Dimensionality Reduction (Optional)

# %%
# Applying PCA for dimensionality reduction
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Visualizing clusters in the reduced dimension
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=data['Cluster'], palette='Set1', s=100, alpha=0.7)
plt.title('PCA-Reduced Cluster Visualization')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()

# %% [markdown]
# ### Explanation:
# PCA helps visualize high-dimensional data in a 2D space, confirming the separation of clusters.

# %% [markdown]
# ### Future encoding before clustering
# <p>a) Generate dummy variables for the 'Gender' column</p>
# b)# Rename column for Gender dummy variables to avoid confusion

# %%
# Generate dummy variables for the 'Genre' column
data = pd.get_dummies(data, columns=['Gender'], drop_first=True)
# Rename column for Genre dummy variables to avoid confusion
data.rename(columns={'Gender_Male': 'Gender'}, inplace=True)

# %% [markdown]
# ### Explanation:
# Dummy Variables Creation:
# The process transforms the string values in the 'Genre' column (like "Male" and "Female") into numerical binary indicators. This means that instead of having a single column with text, you get new columns that represent each category with 0s and 1s.
#
# Column Renaming:
# After creating these new columns, one of them is renamed to 'Gender' for clarity. This makes it easier to understand what the data represents, as 'Gender' is a more intuitive label than 'Genre_Male.'
#
# Summary:
# This approach converts string categories into a numerical format suitable for analysis while ensuring that the column names are clear and meaningful

# %%
data.head()
# Out:
#    CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  Cluster  \
# 0          98   26           60.166809                      45        0
# 1         145   23           76.114737                       7        2
# 2          43   52           38.840794                      41        0
# 3         139   24           74.782947                      14        2
# 4          14   28           19.479408                      77        3
#
#    Gender
# 0    True
# 1    True
# 2   False
# 3   False
# 4    True

# %% [markdown]
# ### Step 9b: Analyzing Cluster Characteristics

# %%
# Analyzing the mean values for each cluster
cluster_summary = data.groupby('Cluster').mean()[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]
round(cluster_summary)
# Out:
#           Age  Annual Income (k$)  Spending Score (1-100)
# Cluster
# 0        43.0                55.0                    50.0
# 1        33.0                87.0                    82.0
# 2        41.0                88.0                    17.0
# 3        26.0                26.0                    79.0
# 4        45.0                26.0                    20.0

# %% [markdown]
# Insight:
# The mean values provide insights into the characteristics of each cluster. We can summarize cluster traits based on these average values.

# %% [markdown]
# ### 9c: Assigning each customers to its various clusters

# %%
# Assuming 'df' is your DataFrame and 'Cluster' is the column with cluster assignments
for cluster_num in data['Cluster'].unique():
    print(f"Customers in Cluster {cluster_num}:")
    print(data[data['Cluster'] == cluster_num][['CustomerID', 'Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']])
    print("\n")
# Out:
# Customers in Cluster 0:
#        CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0              98    True   26           60.166809                      45
# 2              43   False   52           38.840794                      41
# 8             123   False   42           68.190081                      61
# 12             98   False   30           65.478216                      48
# 13            101   False   21           61.167701                      43
# ...           ...     ...  ...                 ...                     ...
# 49992         120    True   48           65.427836                      61
# 49996         117    True   58           64.717618                      40
# 49997         121    True   24           70.974982                      52
# 49998          86    True   52           54.666218                      41
# 49999         101   False   19           63.699743                      42
#
# [20434 rows x 5 columns]
#
#
# ...

# %% [markdown]
# ### 9d. Predicting new customer

# %%
# Step 10: Predictive Function for New Customers
def clustering(age, avg_income, spending_score):
    kmeans_model = pickle.load(open("kmeans.pkl", 'rb'))
    new_customer = np.array([[avg_income, spending_score]])  # Updated to use income and spending score
    predicted_cluster = kmeans_model.predict(new_customer)
    cluster_mapping = {
        0: "Moderate Spenders (Age: Middle-aged, Income: Moderate, Spending: Average)",
        1: "High Spenders (Age: Young, Income: High, Spending: High)",
        2: "Cautious Savers (Age: Middle-aged, Income: High, Spending: Low)",
        3: "Young Lifestyle Spenders (Age: Youngest, Income: Low, Spending: High)",
        4: "Price-Sensitive (Age: Older, Income: Low, Spending: Low)"
    }

    return cluster_mapping.get(predicted_cluster[0], "Unknown Cluster")

# %%
# Test Case
age = 40
avg_income = 30  # Changed from avg_spend to avg_income
spending_score = 4  # Assuming visit_per_week and promotion_interest are not used in prediction

predicted_cluster = clustering(age, avg_income, spending_score)
print(f'New Customer assigned to Cluster: {predicted_cluster}')
# Out:
# New Customer assigned to Cluster: Young Lifestyle Spenders (Age: Youngest, Income: Low)
# C:\Users\Tolu\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Step 11: Conclusion and Marketing Strategy Recommendations

# %% [markdown]
# # Tailoring Our Marketing Strategies Based on Clustering Insights
#
# Hey team, based on our clustering analysis, I’ve put together some insights and suggested strategies to help us better target our customers. Let’s break down the key characteristics for each cluster and discuss how we can approach them with tailored marketing efforts.
#
# ## Cluster Characteristics
#
# Here's what we're seeing in each group:
#
# ### Cluster 0:
# - **Profile**: Middle-aged (average age 43), moderate income ($55k), and average spending behavior (Spending Score: 50).
# - **Gender**: Predominantly male.
# - **Insights**: This group is fairly balanced in terms of spending. They’re not extravagant but do make purchases regularly.
#
# ### Cluster 1:
# - **Profile**: Younger (average age 33), high income ($87k), and high spending behavior (Spending Score: 82).
# - **Gender**: Predominantly female.
# - **Insights**: High-income but cautious spenders. They could be more inclined to save or only spend on items they perceive as valuable.
#
# ### Cluster 2:
# - **Profile**: Older (average age 41), high income ($88k), but low spending score (17).
# - **Gender**: Predominantly male.
# - **Insights**: This group exhibits a high income yet shows low spending behavior, indicating a preference for saving or selective purchasing.
#
# ### Cluster 3:
# - **Profile**: Youngest group (average age 26), lower income ($26k), but with a high spending score (79).
# - **Gender**: Predominantly male.
# - **Insights**: Despite lower income, this group is willing to spend on experiences and products that resonate with them, especially lifestyle-related items.
#
# ### Cluster 4:
# - **Profile**: Older (average age 45), lower income ($26k), and low spending score (20).
# - **Gender**: Predominantly male.
# - **Insights**: This price-sensitive and budget-conscious group is likely to be responsive to value deals and discounts.

# %% [markdown]
# ## Determining the Optimal Number of Clusters
# After analyzing the inertia plot and silhouette scores, it seems that 5 clusters provide a good balance, capturing distinct customer segments effectively.
#
# ## Cluster Assignment Insights
# Each cluster’s demographics and spending behaviors tell a unique story. For example, customers in Cluster 1 have high incomes but a low spending score, indicating they are selective about where they spend their money. This can help us design specific strategies that cater to these preferences.
#
# ## Visualizing the Clusters
# A PCA plot or other visualization tools could further highlight the diversity in behavior across clusters. Some clusters are more dispersed, indicating varied behaviors, while others are tightly grouped, suggesting similar purchasing habits within the cluster.

# %% [markdown]
# ---
#
# By aligning our marketing efforts with these clusters' characteristics, we can deliver more personalized and impactful campaigns. Let’s discuss any thoughts or ideas you may have and refine our approach further.

# %% [markdown]
# ## Next steps

# %% [markdown]
# ### Step 11: Deployment of Our Model Using Streamlit Web App
#
# Deploying our K-means clustering model via Streamlit will provide the marketing team with an interactive tool to:
#
# - **Visualize Customer Segments**: Easily explore clusters based on income and spending scores.
# - **Analyze Cluster Characteristics**: Gain insights into the average age, income, and spending behavior of each segment.
# - **Make Data-Driven Decisions**: Tailor marketing strategies for targeted campaigns, enhancing engagement and ROI.
# - **Adapt Easily**: Quickly update the app with new data or clustering parameters as customer behaviors change.
#
# This deployment is a crucial step in optimizing our marketing efforts and ensuring personalized approaches for each customer segment.

# %% [markdown]
# ---

# %% [markdown]
# ## Project Log
#
# | Date (YYYY-MM-DD) || Project By    | Project Description        |
# | ----------------- | ------- | ------------- | ------------------------- |
# | 204-02-28        |      | Tolulope Israel | ShopMore Retail Customer Segmentation |
#
# <hr>
#
# ## <h3 align="center"> © Turing Corporation 2024. All rights reserved. <h3/>
#
# <p>
